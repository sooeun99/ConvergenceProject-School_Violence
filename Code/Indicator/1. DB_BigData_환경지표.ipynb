# %% [markdown]
# # 환경지표

# %% [markdown]
# # 군집화

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
from scipy.spatial.distance import cdist, pdist
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score
import warnings
warnings.filterwarnings(action='ignore')

# %%
# 학교폭력에 영향을 미치는 변수 상관계수
features = pd.read_csv("C:\sooeun\DATAexam\ConvergenceProject-School_Violence\Data\서울특별시_스케일링_상관관계_유의미한_변수_환경지표.csv", index_col=0)
features['변수'][features['변수'] == '월평균소득금액_백만'] = '월평균소득금액(십만)'
# features.drop(index=[10,11], axis=0,inplace=True)

# %%
data = pd.read_csv("C:\sooeun\DATAexam\ConvergenceProject-School_Violence\Data\서울특별시_스케일링_고등학교지표_유의미한_변수_환경지표.csv", index_col=0)
# data.drop(['국제결혼가정','외국인가정'],axis=1,inplace=True)
data.head(1)

# %%
combined_data = data[features['변수']]
combined_data['학교명'] = data['학교명']
combined_data.set_index('학교명', inplace=True)
combined_data.head(3)

# %%
sd = StandardScaler()
total_sd = pd.DataFrame(sd.fit_transform(combined_data))
total_sd.index = combined_data.index
total_sd.columns = combined_data.columns
total_sd.head(1)

# %% [markdown]
# # Elbow Method(Standard Scaler)

# %%
dist =[]
for i in range(1,20):
    k = KMeans(n_clusters=i,
          init='k-means++',
           n_init=10,
           max_iter=300,
            random_state=800)
    # k.fit(total_sd)
    k.fit(total_sd)
    dist.append(k.inertia_)

plt.plot(range(1,20),dist, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.tight_layout()
plt.show()

# %% [markdown]
# # KMeans(Standard Scaler)

# %%
np.random.seed(3)

# %%
total_sd_value = total_sd.values

#k값을 5로 설정 후 k-means에 적용
kmeans = KMeans(n_clusters =5,   random_state=800).fit(total_sd_value)
kmeans.cluster_centers_

kmeans.predict(pd.DataFrame(total_sd.iloc[0]).T)
# kmeans.predict(total_sd)

# %%
total_sd['cluster'] = kmeans.labels_
total_sd.head(1)

# %%
# 저장 후 주석처리 
total_sd.to_csv("C:\sooeun\DATAexam\ConvergenceProject-School_Violence\Data\서울특별시_고등학교별_cluster_환경지표.csv")

# %%
# TSNE 사용 후 클러스터링
model = TSNE(learning_rate=100,   random_state=800)
transformed = model.fit_transform(total_sd.iloc[:,:10])

xs = transformed[:,0]
ys = transformed[:,1]
plt.scatter(xs,ys,c=kmeans.labels_)

plt.show()

# %% [markdown]
# # 서울시 고등학교 점수

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# 그래프 시각화 라이브러리 
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import rc, font_manager
import warnings
warnings.filterwarnings(action='ignore')

# %%
data = pd.read_csv("C:\sooeun\DATAexam\ConvergenceProject-School_Violence\Data\서울특별시_스케일링_고등학교지표_유의미한_변수_환경지표.csv", index_col=0)
data
# data.drop(['국제결혼가정','외국인가정'],axis=1,inplace=True)

# %%
# 학교폭력에 영향을 미치는 변수 상관계수
features = pd.read_csv("C:\sooeun\DATAexam\ConvergenceProject-School_Violence\Data\서울특별시_스케일링_상관관계_유의미한_변수_환경지표.csv", index_col=0)
features['변수'][features['변수'] == '월평균소득금액_백만'] = '월평균소득금액(십만)'
# features.drop(index=[10,11], axis=0,inplace=True)
features

# %%
# 사용할 컬럼만 추출
combined_data = data[features['변수']]
combined_data['학교명'] = data['학교명']
combined_data.set_index('학교명', inplace=True)
combined_data

# %%
# 학교별 상관관계 합 계산
total_score = []

for col, item in combined_data.T.iteritems():
    total_score.append(sum(item.values * features['상관관계']))

# %%
# total score와 학교폭력신고수를 합친 데이터프레임 생성
school_score = pd.DataFrame(total_score)
school_score.index = combined_data.index
school_score.columns=['score']
school_score.reset_index(inplace=True)
school_score['학교폭력신고수'] = data['학교폭력신고수']

# score 0~10으로
# school_score['score'] -= school_score['score'].min()
# school_score['score'] = school_score['score'] * (100 / school_score['score'].max())
school_score['score']

# %%
# 저장 후 주석처리
school_score.to_csv("C:\sooeun\DATAexam\ConvergenceProject-School_Violence\Data\학교별_종합점수_환경지표.csv")

# %%
# score<->신고수 scatter
plt.scatter(school_score['score'], school_score['학교폭력신고수'], color = 'red')

# fit line 그리기
fit_line = np.polyfit(school_score['score'], school_score['학교폭력신고수'], 1)
fit_line
x_minmax = np.array([min(school_score['score']), max(school_score['score'])]) # x축 최소값, 최대값
fit_y = x_minmax * fit_line[0] + fit_line[1]
plt.plot(x_minmax, fit_y, color = 'blue', markersize=1)

# %% [markdown]
# # 학교별 Total Score

# %%
score = pd.read_csv("C:\sooeun\DATAexam\ConvergenceProject-School_Violence\Data\학교별_종합점수_환경지표.csv", index_col=0)
score.set_index('학교명', inplace=True)
score.head()

# %%
# 각각의 DF에 score 컬럼 추가
total_sd['score'] = score['score']
combined_data['score'] = score['score']

display(total_sd.head(1))
display(combined_data.head(1))

# %% [markdown]
# # 각 Cluster의 평균

# %%
total_sd.groupby('cluster').mean()

# %% [markdown]
# # Silhouette Score

# %%
# KMeans clustering with different number of clusters
scores = []
for n_clusters in range(2, 11):
    kmeans = KMeans(n_clusters=n_clusters, random_state=700)
    kmeans.fit(total_sd.iloc[:,:10])
    score = silhouette_score(total_sd.iloc[:,:10], kmeans.labels_)
    scores.append(score)

# Plotting the silhouette scores
plt.plot(range(2, 11), scores)
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Score")
plt.show()

# %% [markdown]
# # 환경지표

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# 그래프 시각화 라이브러리 
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import rc, font_manager
import warnings
warnings.filterwarnings(action='ignore')

# %%
# 데이터 불어오기 
high_school = pd.read_csv("C:\sooeun\DATAexam\ConvergenceProject-School_Violence\Data\서울특별시_스케일링_고등학교지표_230131.csv",index_col = 0)
high_school.columns
# Out:
# Index(['시도교육청코드', '시도교육청명', '표준학교코드', '학교명', '영문학교명', '학교종류명', '소재지명', '시군구',
#        '관할조직명', '설립명', '도로명우편번호', '도로명주소', '도로명상세주소', '전화번호', '홈페이지주소',
#        '남녀공학구분명', '팩스번호', '고등학교구분명', '산업체특별학급존재여부', '고등학교일반실업구분명',
#        '특수목적고등학교계열명', '입시전후기구분명', '주야구분명', '설립일자', '개교기념일', '수정일', '위도', '경도',
#        '교실안', '특별실,방과후 교실 등', '복도,계단', '화장실', '운동장,체육관,강당 등', '급식실,매점 등',
#        '기숙사', '학원이나학원 근처', '집이나집 근처', 'PC방,노래방,오락실 등', '공원, 놀이터,골목, 공터,뒷산 등',
#        '학교 밖체험활동 장소', '사이버공간', '피해장소_기타', '강요', '금품갈취', '신체폭력', '사이버폭력',
#        '집단따돌림', '피해유형_기타', '등교시간', '수업시간', '쉬는시간', '점심시간', '학교 안방과후 시간',
#        '하교시간', '학교 밖체험활동 시간', '학교 일과가끝난 후', '피해시간_기타', '평균 교육 시간(1학급당)',
#        '나의보호자나친척', '학교선생님', '학교상담실선생님', '학교폭력신고함이나학교 익명게시판', '친구나선·후배',
#        '학교전담경찰관,경찰', '117학교폭력신고센터', '학교 밖상담 기관', '아무에게도알리지않음', '피해 응답 학생 수',
#        '한부모가족지원법수급자_재가보호_가구원수', '국민기초생활보장법수급자_가구원수', '저소득', '중간', '고소득',
#        '생활인구수', '다문화가족', '국제결혼가정', '외국인가정', '단란주점수', '성인게임장수', '술집수', '유흥주점수',
#        '총 신고 수', '청소년비행신고수', '학교폭력신고수', '사건종별가정폭력', '사건종별데이트폭력', '월평균소득금액',
#        '월평균소득금액(십만)', '남고', '남녀공학', '여고', '일반고', '특성화고', '자율고', '특목고', '일반계',
#        '전문계', '500m_inner_police_dept', '500m_inner_cctv',
#        '500m_inner_Harmful_dept'],
#       dtype='object')

# %%
high_school_new = high_school[['시도교육청코드', '시도교육청명', '표준학교코드', '학교명', '영문학교명', '학교종류명', '소재지명', '시군구',
       '관할조직명', '설립명', '도로명우편번호', '도로명주소', '도로명상세주소', '전화번호', '홈페이지주소',
       '남녀공학구분명', '팩스번호', '고등학교구분명', '산업체특별학급존재여부', '고등학교일반실업구분명',
       '특수목적고등학교계열명', '입시전후기구분명', '주야구분명', '설립일자', '개교기념일','위도', '경도',
                               '한부모가족지원법수급자_재가보호_가구원수', '국민기초생활보장법수급자_가구원수',
            '중간', '고소득','성인게임장수','사건종별가정폭력', '사건종별데이트폭력','월평균소득금액(십만)',
            '다문화가족']]
high_school_new
# Out:
#     시도교육청코드    시도교육청명   표준학교코드       학교명                            영문학교명  \
# 0       B10  서울특별시교육청  7010057    가락고등학교                Garak High School
# 1       B10  서울특별시교육청  7011169   가재울고등학교              Gajaeul High School
# 2       B10  서울특별시교육청  7010117    강동고등학교             Kangdong High School
# 3       B10  서울특별시교육청  7010118    강서고등학교              Gangseo High School
# 4       B10  서울특별시교육청  7010270  강서공업고등학교    Gangseo Technical High School
# ..      ...       ...      ...       ...                              ...
# 315     B10  서울특별시교육청  7010766    효문고등학교               Hyomun High School
# 316     B10  서울특별시교육청  7010292  휘경공업고등학교  Hwigyeong Technical High School
# 317     B10  서울특별시교육청  7010267  휘경여자고등학교      Hwikyung Girls` High School
# 318     B10  서울특별시교육청  7010268    휘문고등학교              Whimoon High School
# 319     B10  서울특별시교육청  7011113    휘봉고등학교              HWIBONG High School
#
#     학교종류명   소재지명   시군구     관할조직명 설립명  ...          경도 한부모가족지원법수급자_재가보호_가구원수  \
# 0    고등학교  서울특별시   송파구  서울특별시교육청  공립  ...  127.116426             10.587907
# 1    고등학교  서울특별시  서대문구  서울특별시교육청  공립  ...  126.909530             16.758591
# 2    고등학교  서울특별시   강동구  서울특별시교육청  사립  ...  127.160668             14.148759
# 3    고등학교  서울특별시   양천구  서울특별시교육청  사립  ...  126.865771             15.982703
# 4    고등학교  서울특별시   강서구  서울특별시교육청  공립  ...  126.816182             20.076996
# ..    ...    ...   ...       ...  ..  ...         ...                   ...
# 315  고등학교  서울특별시   도봉구  서울특별시교육청  공립  ...  127.018400             27.773168
# 316  고등학교  서울특별시  동대문구  서울특별시교육청  공립  ...  127.069451             17.442884
# 317  고등학교  서울특별시  동대문구  서울특별시교육청  사립  ...  127.067434             17.442884
# 318  고등학교  서울특별시   강남구  서울특별시교육청  사립  ...  127.061994              6.136110
# 319  고등학교  서울특별시  동대문구  서울특별시교육청  공립  ...  127.068941             17.442884
#
#     국민기초생활보장법수급자_가구원수    중간   고소득 성인게임장수  사건종별가정폭력 사건종별데이트폭력 월평균소득금액(십만)  \
# 0           41.944982  61.9  21.3   10.0  4.611694  0.673981    39.69562
# 1           47.709712  46.9  20.2    5.0  3.501553  0.504236    39.43923
# 2           48.663157  52.6  19.8   15.0  4.690014  0.769964    33.36210
# 3           58.270272  62.8  13.5    6.0  4.280519  0.412517    35.63309
# 4           67.130300  62.7  17.2   15.0  5.099763  1.060769    31.65221
# ..                ...   ...   ...    ...       ...       ...         ...
# 315         85.260808  56.2  29.7   16.0  5.916945  0.840188    27.13315
# 316         53.493406  46.3  22.0   16.0  4.093672  0.909075    30.11303
# 317         53.493406  46.3  22.0   16.0  4.093672  0.909075    30.11303
# 318         30.717739  44.9  34.7    2.0  2.146930  1.160593    47.99007
# 319         53.493406  46.3  22.0   16.0  4.093672  0.909075    30.11303
#
#         다문화가족
# 0    1.666742
# 1    1.741705
# 2    1.334094
# 3    2.478195
# 4    2.591578
# ..        ...
# 315  1.507146
# 316  3.348503
# 317  3.348503
# 318  1.330665
# 319  3.348503
#
# [320 rows x 36 columns]

# %%
high_school_new.rename(columns = {'월평균소득금액(십만)':'월평균소득금액(백만)'},inplace=True)
high_school_new
# Out:
#     시도교육청코드    시도교육청명   표준학교코드       학교명                            영문학교명  \
# 0       B10  서울특별시교육청  7010057    가락고등학교                Garak High School
# 1       B10  서울특별시교육청  7011169   가재울고등학교              Gajaeul High School
# 2       B10  서울특별시교육청  7010117    강동고등학교             Kangdong High School
# 3       B10  서울특별시교육청  7010118    강서고등학교              Gangseo High School
# 4       B10  서울특별시교육청  7010270  강서공업고등학교    Gangseo Technical High School
# ..      ...       ...      ...       ...                              ...
# 315     B10  서울특별시교육청  7010766    효문고등학교               Hyomun High School
# 316     B10  서울특별시교육청  7010292  휘경공업고등학교  Hwigyeong Technical High School
# 317     B10  서울특별시교육청  7010267  휘경여자고등학교      Hwikyung Girls` High School
# 318     B10  서울특별시교육청  7010268    휘문고등학교              Whimoon High School
# 319     B10  서울특별시교육청  7011113    휘봉고등학교              HWIBONG High School
#
#     학교종류명   소재지명   시군구     관할조직명 설립명  ...          경도 한부모가족지원법수급자_재가보호_가구원수  \
# 0    고등학교  서울특별시   송파구  서울특별시교육청  공립  ...  127.116426             10.587907
# 1    고등학교  서울특별시  서대문구  서울특별시교육청  공립  ...  126.909530             16.758591
# 2    고등학교  서울특별시   강동구  서울특별시교육청  사립  ...  127.160668             14.148759
# 3    고등학교  서울특별시   양천구  서울특별시교육청  사립  ...  126.865771             15.982703
# 4    고등학교  서울특별시   강서구  서울특별시교육청  공립  ...  126.816182             20.076996
# ..    ...    ...   ...       ...  ..  ...         ...                   ...
# 315  고등학교  서울특별시   도봉구  서울특별시교육청  공립  ...  127.018400             27.773168
# 316  고등학교  서울특별시  동대문구  서울특별시교육청  공립  ...  127.069451             17.442884
# 317  고등학교  서울특별시  동대문구  서울특별시교육청  사립  ...  127.067434             17.442884
# 318  고등학교  서울특별시   강남구  서울특별시교육청  사립  ...  127.061994              6.136110
# 319  고등학교  서울특별시  동대문구  서울특별시교육청  공립  ...  127.068941             17.442884
#
#     국민기초생활보장법수급자_가구원수    중간   고소득 성인게임장수  사건종별가정폭력 사건종별데이트폭력 월평균소득금액(백만)  \
# 0           41.944982  61.9  21.3   10.0  4.611694  0.673981    39.69562
# 1           47.709712  46.9  20.2    5.0  3.501553  0.504236    39.43923
# 2           48.663157  52.6  19.8   15.0  4.690014  0.769964    33.36210
# 3           58.270272  62.8  13.5    6.0  4.280519  0.412517    35.63309
# 4           67.130300  62.7  17.2   15.0  5.099763  1.060769    31.65221
# ..                ...   ...   ...    ...       ...       ...         ...
# 315         85.260808  56.2  29.7   16.0  5.916945  0.840188    27.13315
# 316         53.493406  46.3  22.0   16.0  4.093672  0.909075    30.11303
# 317         53.493406  46.3  22.0   16.0  4.093672  0.909075    30.11303
# 318         30.717739  44.9  34.7    2.0  2.146930  1.160593    47.99007
# 319         53.493406  46.3  22.0   16.0  4.093672  0.909075    30.11303
#
#         다문화가족
# 0    1.666742
# 1    1.741705
# 2    1.334094
# 3    2.478195
# 4    2.591578
# ..        ...
# 315  1.507146
# 316  3.348503
# 317  3.348503
# 318  1.330665
# 319  3.348503
#
# [320 rows x 36 columns]

# %%
score = pd.read_csv("C:\sooeun\DATAexam\ConvergenceProject-School_Violence\Data\학교별_종합점수_환경지표.csv", index_col=0)
score_new = score[['학교명','score']]
score_new
# Out:
#           학교명      score
# 0      가락고등학교  48.715229
# 1     가재울고등학교  46.193799
# 2      강동고등학교  55.148267
# 3      강서고등학교  65.103834
# 4    강서공업고등학교  77.831186
# ..        ...        ...
# 315    효문고등학교  89.946627
# 316  휘경공업고등학교  58.574818
# 317  휘경여자고등학교  58.574818
# 318    휘문고등학교  19.071217
# 319    휘봉고등학교  58.574818
#
# [320 rows x 2 columns]

# %%
data1 = pd.merge(high_school_new, score_new, on=['학교명'], how='outer', sort=True)
data1
# Out:
#     시도교육청코드    시도교육청명   표준학교코드       학교명                            영문학교명  \
# 0       B10  서울특별시교육청  7010057    가락고등학교                Garak High School
# 1       B10  서울특별시교육청  7011169   가재울고등학교              Gajaeul High School
# 2       B10  서울특별시교육청  7010117    강동고등학교             Kangdong High School
# 3       B10  서울특별시교육청  7010118    강서고등학교              Gangseo High School
# 4       B10  서울특별시교육청  7010270  강서공업고등학교    Gangseo Technical High School
# ..      ...       ...      ...       ...                              ...
# 315     B10  서울특별시교육청  7010766    효문고등학교               Hyomun High School
# 316     B10  서울특별시교육청  7010292  휘경공업고등학교  Hwigyeong Technical High School
# 317     B10  서울특별시교육청  7010267  휘경여자고등학교      Hwikyung Girls` High School
# 318     B10  서울특별시교육청  7010268    휘문고등학교              Whimoon High School
# 319     B10  서울특별시교육청  7011113    휘봉고등학교              HWIBONG High School
#
#     학교종류명   소재지명   시군구     관할조직명 설립명  ...  한부모가족지원법수급자_재가보호_가구원수  \
# 0    고등학교  서울특별시   송파구  서울특별시교육청  공립  ...              10.587907
# 1    고등학교  서울특별시  서대문구  서울특별시교육청  공립  ...              16.758591
# 2    고등학교  서울특별시   강동구  서울특별시교육청  사립  ...              14.148759
# 3    고등학교  서울특별시   양천구  서울특별시교육청  사립  ...              15.982703
# 4    고등학교  서울특별시   강서구  서울특별시교육청  공립  ...              20.076996
# ..    ...    ...   ...       ...  ..  ...                    ...
# 315  고등학교  서울특별시   도봉구  서울특별시교육청  공립  ...              27.773168
# 316  고등학교  서울특별시  동대문구  서울특별시교육청  공립  ...              17.442884
# 317  고등학교  서울특별시  동대문구  서울특별시교육청  사립  ...              17.442884
# 318  고등학교  서울특별시   강남구  서울특별시교육청  사립  ...               6.136110
# 319  고등학교  서울특별시  동대문구  서울특별시교육청  공립  ...              17.442884
#
#     국민기초생활보장법수급자_가구원수    중간   고소득 성인게임장수  사건종별가정폭력 사건종별데이트폭력 월평균소득금액(백만)  \
# 0           41.944982  61.9  21.3   10.0  4.611694  0.673981    39.69562
# 1           47.709712  46.9  20.2    5.0  3.501553  0.504236    39.43923
# 2           48.663157  52.6  19.8   15.0  4.690014  0.769964    33.36210
# 3           58.270272  62.8  13.5    6.0  4.280519  0.412517    35.63309
# 4           67.130300  62.7  17.2   15.0  5.099763  1.060769    31.65221
# ..                ...   ...   ...    ...       ...       ...         ...
# 315         85.260808  56.2  29.7   16.0  5.916945  0.840188    27.13315
# 316         53.493406  46.3  22.0   16.0  4.093672  0.909075    30.11303
# 317         53.493406  46.3  22.0   16.0  4.093672  0.909075    30.11303
# 318         30.717739  44.9  34.7    2.0  2.146930  1.160593    47.99007
# 319         53.493406  46.3  22.0   16.0  4.093672  0.909075    30.11303
#
#         다문화가족      score
# 0    1.666742  48.715229
# 1    1.741705  46.193799
# 2    1.334094  55.148267
# 3    2.478195  65.103834
# 4    2.591578  77.831186
# ..        ...        ...
# 315  1.507146  89.946627
# 316  3.348503  58.574818
# 317  3.348503  58.574818
# 318  1.330665  19.071217
# 319  3.348503  58.574818
#
# [320 rows x 37 columns]

# %%
cluster = pd.read_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/서울특별시_고등학교별_cluster_환경지표.csv")
cluster
cluster_new = cluster[['학교명','cluster']]
cluster_new
# Out:
#           학교명  cluster
# 0      가락고등학교        3
# 1     가재울고등학교        2
# 2      강동고등학교        2
# 3      강서고등학교        2
# 4    강서공업고등학교        1
# ..        ...      ...
# 315    효문고등학교        1
# 316  휘경공업고등학교        2
# 317  휘경여자고등학교        2
# 318    휘문고등학교        3
# 319    휘봉고등학교        2
#
# [320 rows x 2 columns]

# %%
data2 = pd.merge(data1, cluster_new, on=['학교명'], how='outer', sort=True)
data2
# Out:
#     시도교육청코드    시도교육청명   표준학교코드       학교명                            영문학교명  \
# 0       B10  서울특별시교육청  7010057    가락고등학교                Garak High School
# 1       B10  서울특별시교육청  7011169   가재울고등학교              Gajaeul High School
# 2       B10  서울특별시교육청  7010117    강동고등학교             Kangdong High School
# 3       B10  서울특별시교육청  7010118    강서고등학교              Gangseo High School
# 4       B10  서울특별시교육청  7010270  강서공업고등학교    Gangseo Technical High School
# ..      ...       ...      ...       ...                              ...
# 315     B10  서울특별시교육청  7010766    효문고등학교               Hyomun High School
# 316     B10  서울특별시교육청  7010292  휘경공업고등학교  Hwigyeong Technical High School
# 317     B10  서울특별시교육청  7010267  휘경여자고등학교      Hwikyung Girls` High School
# 318     B10  서울특별시교육청  7010268    휘문고등학교              Whimoon High School
# 319     B10  서울특별시교육청  7011113    휘봉고등학교              HWIBONG High School
#
#     학교종류명   소재지명   시군구     관할조직명 설립명  ...  국민기초생활보장법수급자_가구원수    중간   고소득  \
# 0    고등학교  서울특별시   송파구  서울특별시교육청  공립  ...          41.944982  61.9  21.3
# 1    고등학교  서울특별시  서대문구  서울특별시교육청  공립  ...          47.709712  46.9  20.2
# 2    고등학교  서울특별시   강동구  서울특별시교육청  사립  ...          48.663157  52.6  19.8
# 3    고등학교  서울특별시   양천구  서울특별시교육청  사립  ...          58.270272  62.8  13.5
# 4    고등학교  서울특별시   강서구  서울특별시교육청  공립  ...          67.130300  62.7  17.2
# ..    ...    ...   ...       ...  ..  ...                ...   ...   ...
# 315  고등학교  서울특별시   도봉구  서울특별시교육청  공립  ...          85.260808  56.2  29.7
# 316  고등학교  서울특별시  동대문구  서울특별시교육청  공립  ...          53.493406  46.3  22.0
# 317  고등학교  서울특별시  동대문구  서울특별시교육청  사립  ...          53.493406  46.3  22.0
# 318  고등학교  서울특별시   강남구  서울특별시교육청  사립  ...          30.717739  44.9  34.7
# 319  고등학교  서울특별시  동대문구  서울특별시교육청  공립  ...          53.493406  46.3  22.0
#
#     성인게임장수  사건종별가정폭력 사건종별데이트폭력 월평균소득금액(백만)     다문화가족      score cluster
# 0     10.0  4.611694  0.673981    39.69562  1.666742  48.715229       3
# 1      5.0  3.501553  0.504236    39.43923  1.741705  46.193799       2
# 2     15.0  4.690014  0.769964    33.36210  1.334094  55.148267       2
# 3      6.0  4.280519  0.412517    35.63309  2.478195  65.103834       2
# 4     15.0  5.099763  1.060769    31.65221  2.591578  77.831186       1
# ..     ...       ...       ...         ...       ...        ...     ...
# 315   16.0  5.916945  0.840188    27.13315  1.507146  89.946627       1
# 316   16.0  4.093672  0.909075    30.11303  3.348503  58.574818       2
# 317   16.0  4.093672  0.909075    30.11303  3.348503  58.574818       2
# 318    2.0  2.146930  1.160593    47.99007  1.330665  19.071217       3
# 319   16.0  4.093672  0.909075    30.11303  3.348503  58.574818       2
#
# [320 rows x 38 columns]

# %%
data2.rename(columns = {'중간':'소득인식수준_중간소득','고소득':'소득인식수준_고소득'},inplace=True)
data2.columns
# Out:
# Index(['시도교육청코드', '시도교육청명', '표준학교코드', '학교명', '영문학교명', '학교종류명', '소재지명', '시군구',
#        '관할조직명', '설립명', '도로명우편번호', '도로명주소', '도로명상세주소', '전화번호', '홈페이지주소',
#        '남녀공학구분명', '팩스번호', '고등학교구분명', '산업체특별학급존재여부', '고등학교일반실업구분명',
#        '특수목적고등학교계열명', '입시전후기구분명', '주야구분명', '설립일자', '개교기념일', '위도', '경도',
#        '한부모가족지원법수급자_재가보호_가구원수', '국민기초생활보장법수급자_가구원수', '소득인식수준_중간소득',
#        '소득인식수준_고소득', '성인게임장수', '사건종별가정폭력', '사건종별데이트폭력', '월평균소득금액(백만)', '다문화가족',
#        'score', 'cluster'],
#       dtype='object')

# %%
data2["학교폭력위험도"] = [
    "낮음" if x == 0 else
    "매우높음" if x == 1 else 
    "보통" if x == 2 else 
    "매우낮음" if x == 3 else  
    "높음" for x in data2.cluster]
data2
# Out:
#     시도교육청코드    시도교육청명   표준학교코드       학교명                            영문학교명  \
# 0       B10  서울특별시교육청  7010057    가락고등학교                Garak High School
# 1       B10  서울특별시교육청  7011169   가재울고등학교              Gajaeul High School
# 2       B10  서울특별시교육청  7010117    강동고등학교             Kangdong High School
# 3       B10  서울특별시교육청  7010118    강서고등학교              Gangseo High School
# 4       B10  서울특별시교육청  7010270  강서공업고등학교    Gangseo Technical High School
# ..      ...       ...      ...       ...                              ...
# 315     B10  서울특별시교육청  7010766    효문고등학교               Hyomun High School
# 316     B10  서울특별시교육청  7010292  휘경공업고등학교  Hwigyeong Technical High School
# 317     B10  서울특별시교육청  7010267  휘경여자고등학교      Hwikyung Girls` High School
# 318     B10  서울특별시교육청  7010268    휘문고등학교              Whimoon High School
# 319     B10  서울특별시교육청  7011113    휘봉고등학교              HWIBONG High School
#
#     학교종류명   소재지명   시군구     관할조직명 설립명  ...  소득인식수준_중간소득 소득인식수준_고소득 성인게임장수  \
# 0    고등학교  서울특별시   송파구  서울특별시교육청  공립  ...         61.9       21.3   10.0
# 1    고등학교  서울특별시  서대문구  서울특별시교육청  공립  ...         46.9       20.2    5.0
# 2    고등학교  서울특별시   강동구  서울특별시교육청  사립  ...         52.6       19.8   15.0
# 3    고등학교  서울특별시   양천구  서울특별시교육청  사립  ...         62.8       13.5    6.0
# 4    고등학교  서울특별시   강서구  서울특별시교육청  공립  ...         62.7       17.2   15.0
# ..    ...    ...   ...       ...  ..  ...          ...        ...    ...
# 315  고등학교  서울특별시   도봉구  서울특별시교육청  공립  ...         56.2       29.7   16.0
# 316  고등학교  서울특별시  동대문구  서울특별시교육청  공립  ...         46.3       22.0   16.0
# 317  고등학교  서울특별시  동대문구  서울특별시교육청  사립  ...         46.3       22.0   16.0
# 318  고등학교  서울특별시   강남구  서울특별시교육청  사립  ...         44.9       34.7    2.0
# 319  고등학교  서울특별시  동대문구  서울특별시교육청  공립  ...         46.3       22.0   16.0
#
#      사건종별가정폭력 사건종별데이트폭력 월평균소득금액(백만)     다문화가족      score cluster 학교폭력위험도
# 0    4.611694  0.673981    39.69562  1.666742  48.715229       3    매우낮음
# 1    3.501553  0.504236    39.43923  1.741705  46.193799       2      보통
# 2    4.690014  0.769964    33.36210  1.334094  55.148267       2      보통
# 3    4.280519  0.412517    35.63309  2.478195  65.103834       2      보통
# 4    5.099763  1.060769    31.65221  2.591578  77.831186       1    매우높음
# ..        ...       ...         ...       ...        ...     ...     ...
# 315  5.916945  0.840188    27.13315  1.507146  89.946627       1    매우높음
# 316  4.093672  0.909075    30.11303  3.348503  58.574818       2      보통
# 317  4.093672  0.909075    30.11303  3.348503  58.574818       2      보통
# 318  2.146930  1.160593    47.99007  1.330665  19.071217       3    매우낮음
# 319  4.093672  0.909075    30.11303  3.348503  58.574818       2      보통
#
# [320 rows x 39 columns]

# %%
data2.rename(columns = {'score':'환경지표_score','cluster':'환경지표_cluster','학교폭력위험도':'환경지표_학교폭력위험도'},inplace=True)
data2.columns
# Out:
# Index(['시도교육청코드', '시도교육청명', '표준학교코드', '학교명', '영문학교명', '학교종류명', '소재지명', '시군구',
#        '관할조직명', '설립명', '도로명우편번호', '도로명주소', '도로명상세주소', '전화번호', '홈페이지주소',
#        '남녀공학구분명', '팩스번호', '고등학교구분명', '산업체특별학급존재여부', '고등학교일반실업구분명',
#        '특수목적고등학교계열명', '입시전후기구분명', '주야구분명', '설립일자', '개교기념일', '위도', '경도',
#        '한부모가족지원법수급자_재가보호_가구원수', '국민기초생활보장법수급자_가구원수', '소득인식수준_중간소득',
#        '소득인식수준_고소득', '성인게임장수', '사건종별가정폭력', '사건종별데이트폭력', '월평균소득금액(백만)', '다문화가족',
#        '환경지표_score', '환경지표_cluster', '환경지표_학교폭력위험도'],
#       dtype='object')

# %%
data2.dtypes
# Out:
# 시도교육청코드                   object
# 시도교육청명                    object
# 표준학교코드                     int64
# 학교명                       object
# 영문학교명                     object
# 학교종류명                     object
# 소재지명                      object
# 시군구                       object
# 관할조직명                     object
# 설립명                       object
# 도로명우편번호                    int64
# 도로명주소                     object
# 도로명상세주소                   object
# 전화번호                      object
# 홈페이지주소                    object
# 남녀공학구분명                   object
# 팩스번호                      object
# 고등학교구분명                   object
# 산업체특별학급존재여부               object
# 고등학교일반실업구분명               object
# 특수목적고등학교계열명               object
# 입시전후기구분명                  object
# 주야구분명                     object
# 설립일자                       int64
# 개교기념일                      int64
# 위도                       float64
# 경도                       float64
# 한부모가족지원법수급자_재가보호_가구원수    float64
# 국민기초생활보장법수급자_가구원수        float64
# 소득인식수준_중간소득              float64
# 소득인식수준_고소득               float64
# 성인게임장수                   float64
# 사건종별가정폭력                 float64
# 사건종별데이트폭력                float64
# 월평균소득금액(백만)              float64
# 다문화가족                    float64
# 환경지표_score               float64
# 환경지표_cluster               int64
# 환경지표_학교폭력위험도              object
# dtype: object

# %%
# 저장 후 주석처리 
data2.to_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/서울특별시_고등학교_환경지표_school_region.csv")

# %%
data2.columns
# Out:
# Index(['시도교육청코드', '시도교육청명', '표준학교코드', '학교명', '영문학교명', '학교종류명', '소재지명', '시군구',
#        '관할조직명', '설립명', '도로명우편번호', '도로명주소', '도로명상세주소', '전화번호', '홈페이지주소',
#        '남녀공학구분명', '팩스번호', '고등학교구분명', '산업체특별학급존재여부', '고등학교일반실업구분명',
#        '특수목적고등학교계열명', '입시전후기구분명', '주야구분명', '설립일자', '개교기념일', '위도', '경도',
#        '한부모가족지원법수급자_재가보호_가구원수', '국민기초생활보장법수급자_가구원수', '소득인식수준_중간소득',
#        '소득인식수준_고소득', '성인게임장수', '사건종별가정폭력', '사건종별데이트폭력', '월평균소득금액(백만)', '다문화가족',
#        '환경지표_score', '환경지표_cluster', '환경지표_학교폭력위험도'],
#       dtype='object')

# %% [markdown]
# # DB_학교정보

# %%
school_data = data2[['시도교육청코드', '시도교육청명', '표준학교코드', '학교명', '영문학교명', '학교종류명', '소재지명', '시군구',
       '관할조직명', '설립명', '도로명우편번호', '도로명주소', '도로명상세주소', '전화번호', '홈페이지주소',
       '남녀공학구분명', '팩스번호', '고등학교구분명', '산업체특별학급존재여부', '고등학교일반실업구분명',
       '특수목적고등학교계열명', '입시전후기구분명', '주야구분명', '설립일자', '개교기념일', '위도', '경도']]
school_data
# Out:
#     시도교육청코드    시도교육청명   표준학교코드       학교명                            영문학교명  \
# 0       B10  서울특별시교육청  7010057    가락고등학교                Garak High School
# 1       B10  서울특별시교육청  7011169   가재울고등학교              Gajaeul High School
# 2       B10  서울특별시교육청  7010117    강동고등학교             Kangdong High School
# 3       B10  서울특별시교육청  7010118    강서고등학교              Gangseo High School
# 4       B10  서울특별시교육청  7010270  강서공업고등학교    Gangseo Technical High School
# ..      ...       ...      ...       ...                              ...
# 315     B10  서울특별시교육청  7010766    효문고등학교               Hyomun High School
# 316     B10  서울특별시교육청  7010292  휘경공업고등학교  Hwigyeong Technical High School
# 317     B10  서울특별시교육청  7010267  휘경여자고등학교      Hwikyung Girls` High School
# 318     B10  서울특별시교육청  7010268    휘문고등학교              Whimoon High School
# 319     B10  서울특별시교육청  7011113    휘봉고등학교              HWIBONG High School
#
#     학교종류명   소재지명   시군구     관할조직명 설립명  ...  고등학교구분명 산업체특별학급존재여부 고등학교일반실업구분명  \
# 0    고등학교  서울특별시   송파구  서울특별시교육청  공립  ...      일반고           N         일반계
# 1    고등학교  서울특별시  서대문구  서울특별시교육청  공립  ...      일반고           N         일반계
# 2    고등학교  서울특별시   강동구  서울특별시교육청  사립  ...      일반고           N         일반계
# 3    고등학교  서울특별시   양천구  서울특별시교육청  사립  ...      일반고           N         일반계
# 4    고등학교  서울특별시   강서구  서울특별시교육청  공립  ...     특성화고           N         전문계
# ..    ...    ...   ...       ...  ..  ...      ...         ...         ...
# 315  고등학교  서울특별시   도봉구  서울특별시교육청  공립  ...      일반고           N         일반계
# 316  고등학교  서울특별시  동대문구  서울특별시교육청  공립  ...     특성화고           N         전문계
# 317  고등학교  서울특별시  동대문구  서울특별시교육청  사립  ...      일반고           N         일반계
# 318  고등학교  서울특별시   강남구  서울특별시교육청  사립  ...      자율고           N         일반계
# 319  고등학교  서울특별시  동대문구  서울특별시교육청  공립  ...      일반고           N         일반계
#
#     특수목적고등학교계열명 입시전후기구분명 주야구분명      설립일자     개교기념일         위도          경도
# 0           NaN       후기    주간  19881223  19890428  37.501076  127.116426
# 1           NaN       후기    주간  20130301  20130501  37.574364  126.909530
# 2           NaN       후기    주간  19841217  19850908  37.549917  127.160668
# 3           NaN       후기    주간  19831101  19831101  37.536316  126.865771
# 4           NaN       전기    주간  19940105  19940105  37.576034  126.816182
# ..          ...      ...   ...       ...       ...        ...         ...
# 315         NaN       후기    주간  20051229  20060605  37.652699  127.018400
# 316         NaN       전기    주간  19971220  19980702  37.585153  127.069451
# 317         NaN       후기    주간  19750303  19750519  37.581901  127.067434
# 318         NaN       전기    주간  19060501  19060501  37.505289  127.061994
# 319         NaN       후기    주간  20120106  20120501  37.586372  127.068941
#
# [320 rows x 27 columns]

# %%
# 저장 후 주석처리 
school_data.to_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/DB_서울특별시_고등학교_정보.csv")

# %% [markdown]
# # DB_환경지표

# %%
db_enviro = data2[['시군구','환경지표_score', '환경지표_cluster', '환경지표_학교폭력위험도']]
db_enviro
# Out:
#       시군구  환경지표_score  환경지표_cluster 환경지표_학교폭력위험도
# 0     송파구   48.715229             3         매우낮음
# 1    서대문구   46.193799             2           보통
# 2     강동구   55.148267             2           보통
# 3     양천구   65.103834             2           보통
# 4     강서구   77.831186             1         매우높음
# ..    ...         ...           ...          ...
# 315   도봉구   89.946627             1         매우높음
# 316  동대문구   58.574818             2           보통
# 317  동대문구   58.574818             2           보통
# 318   강남구   19.071217             3         매우낮음
# 319  동대문구   58.574818             2           보통
#
# [320 rows x 4 columns]

# %%
db_enviro_new = db_enviro.drop_duplicates()
db_enviro_new
# Out:
#       시군구  환경지표_score  환경지표_cluster 환경지표_학교폭력위험도
# 0     송파구   48.715229             3         매우낮음
# 1    서대문구   46.193799             2           보통
# 2     강동구   55.148267             2           보통
# 3     양천구   65.103834             2           보통
# 4     강서구   77.831186             1         매우높음
# 6     강남구   19.071217             3         매우낮음
# 7     광진구   60.193732             2           보통
# 9     노원구   73.827367             2           보통
# 10    종로구   32.341505             0           낮음
# 12    성북구   50.472787             2           보통
# 13    동작구   41.254694             2           보통
# 17    마포구   36.219280             3         매우낮음
# 19    구로구   70.972259             4           높음
# 20    성동구   38.346846             3         매우낮음
# 21   동대문구   58.574818             2           보통
# 28   영등포구   25.401159             3         매우낮음
# 32    관악구   77.867433             4           높음
# 43    금천구   90.229114             1         매우높음
# 49    도봉구   89.946627             1         매우높음
# 53     중구   35.480837             0           낮음
# 56    은평구   74.881966             2           보통
# 79    서초구   20.295262             3         매우낮음
# 91    중랑구   98.701102             1         매우높음
# 105   강북구  105.369939             1         매우높음
# 109   용산구   38.593980             3         매우낮음

# %%
db_enviro_new.sort_values('시군구',ascending=True,inplace=True)
db_enviro_new
# Out:
#       시군구  환경지표_score  환경지표_cluster 환경지표_학교폭력위험도
# 6     강남구   19.071217             3         매우낮음
# 2     강동구   55.148267             2           보통
# 105   강북구  105.369939             1         매우높음
# 4     강서구   77.831186             1         매우높음
# 32    관악구   77.867433             4           높음
# 7     광진구   60.193732             2           보통
# 19    구로구   70.972259             4           높음
# 43    금천구   90.229114             1         매우높음
# 9     노원구   73.827367             2           보통
# 49    도봉구   89.946627             1         매우높음
# 21   동대문구   58.574818             2           보통
# 13    동작구   41.254694             2           보통
# 17    마포구   36.219280             3         매우낮음
# 1    서대문구   46.193799             2           보통
# 79    서초구   20.295262             3         매우낮음
# 20    성동구   38.346846             3         매우낮음
# 12    성북구   50.472787             2           보통
# 0     송파구   48.715229             3         매우낮음
# 3     양천구   65.103834             2           보통
# 28   영등포구   25.401159             3         매우낮음
# 109   용산구   38.593980             3         매우낮음
# 56    은평구   74.881966             2           보통
# 10    종로구   32.341505             0           낮음
# 53     중구   35.480837             0           낮음
# 91    중랑구   98.701102             1         매우높음

# %%
db_enviro_new.reset_index(drop=False, inplace=True)
db_enviro_new
# Out:
#     index   시군구  환경지표_score  환경지표_cluster 환경지표_학교폭력위험도
# 0       6   강남구   19.071217             3         매우낮음
# 1       2   강동구   55.148267             2           보통
# 2     105   강북구  105.369939             1         매우높음
# 3       4   강서구   77.831186             1         매우높음
# 4      32   관악구   77.867433             4           높음
# 5       7   광진구   60.193732             2           보통
# 6      19   구로구   70.972259             4           높음
# 7      43   금천구   90.229114             1         매우높음
# 8       9   노원구   73.827367             2           보통
# 9      49   도봉구   89.946627             1         매우높음
# 10     21  동대문구   58.574818             2           보통
# 11     13   동작구   41.254694             2           보통
# 12     17   마포구   36.219280             3         매우낮음
# 13      1  서대문구   46.193799             2           보통
# 14     79   서초구   20.295262             3         매우낮음
# 15     20   성동구   38.346846             3         매우낮음
# 16     12   성북구   50.472787             2           보통
# 17      0   송파구   48.715229             3         매우낮음
# 18      3   양천구   65.103834             2           보통
# 19     28  영등포구   25.401159             3         매우낮음
# 20    109   용산구   38.593980             3         매우낮음
# 21     56   은평구   74.881966             2           보통
# 22     10   종로구   32.341505             0           낮음
# 23     53    중구   35.480837             0           낮음
# 24     91   중랑구   98.701102             1         매우높음

# %%
db_enviro_new_2 = db_enviro_new.drop(['index'],axis=1)
db_enviro_new_2
# Out:
#      시군구  환경지표_score  환경지표_cluster 환경지표_학교폭력위험도
# 0    강남구   19.071217             3         매우낮음
# 1    강동구   55.148267             2           보통
# 2    강북구  105.369939             1         매우높음
# 3    강서구   77.831186             1         매우높음
# 4    관악구   77.867433             4           높음
# 5    광진구   60.193732             2           보통
# 6    구로구   70.972259             4           높음
# 7    금천구   90.229114             1         매우높음
# 8    노원구   73.827367             2           보통
# 9    도봉구   89.946627             1         매우높음
# 10  동대문구   58.574818             2           보통
# 11   동작구   41.254694             2           보통
# 12   마포구   36.219280             3         매우낮음
# 13  서대문구   46.193799             2           보통
# 14   서초구   20.295262             3         매우낮음
# 15   성동구   38.346846             3         매우낮음
# 16   성북구   50.472787             2           보통
# 17   송파구   48.715229             3         매우낮음
# 18   양천구   65.103834             2           보통
# 19  영등포구   25.401159             3         매우낮음
# 20   용산구   38.593980             3         매우낮음
# 21   은평구   74.881966             2           보통
# 22   종로구   32.341505             0           낮음
# 23    중구   35.480837             0           낮음
# 24   중랑구   98.701102             1         매우높음

# %%
# 저장 후 주석처리 
db_enviro_new_2.to_csv("C:/sooeun/DATAexam/ConvergenceProject-School_Violence/Data/DB_서울특별시_고등학교_학교폭력_환경지표.csv")
